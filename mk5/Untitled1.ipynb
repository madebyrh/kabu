# %%
import pandas as pd
import numpy as np
from os import path
from pathlib import Path

# cat = '東証二部'

df = pd.read_csv('./moving_average.csv', encoding='sjis')

file_list = list(Path('./price_data').glob('*csv'))
file_name = path.basename(file_list[-1])
# file_name

l_df = pd.read_csv('./price_data/' + file_name, encoding='sjis')

# 変更
l_df = l_df[['SC', '株価', '市場']]
l_df.drop(l_df.index[0:2], inplace=True)
# l_df = l_df[l_df['市場'] == cat]
l_df = l_df[l_df['市場'].isnull() == False]
l_df = l_df[l_df['株価'] != '-']
l_df['株価'] = l_df['株価'].astype(str).astype(np.float64)



# compare_data = pd.merge(df, l_df, on='SC', how='left')
compare_data = pd.merge(df, l_df, on='SC')
compare_data.drop(compare_data.columns[-1], axis=1,inplace=True)

# %%
compare_data['compare'] = compare_data[compare_data.columns[-2]] - compare_data[compare_data.columns[-1]]
# compare_data

tmp_data = compare_data.loc[compare_data['compare'] > .0]
tmp_data['rate'] = tmp_data['compare'] / tmp_data[tmp_data.columns[-3]]
tmp_data2 = tmp_data2[tmp_data2[tmp_data2.columns[2]] < tmp_data2[tmp_data2.columns[3]]]
tmp_data2 = tmp_data.sort_values(by='rate', ascending=True)[0:100]
# Out:
# C:\Users\ficti\anaconda3\envs\DataScience\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
tmp_data2
# Out:
#         SC            名称  20200611  20200612      株価  compare      rate
# 2588  7433            伯東    989.04    990.04   990.0     0.04  0.000040
# 637   3171     マックスバリュ九州   2401.16   2404.12  2404.0     0.12  0.000050
# 1706  5706        三井金属鉱業   2240.08   2247.12  2247.0     0.12  0.000053
# 1677  5481        山陽特殊製鋼    997.08    997.08   997.0     0.08  0.000080
# 1477  4765      モーニングスター    370.64    371.04   371.0     0.04  0.000108
# ...    ...           ...       ...       ...     ...      ...       ...
# 502   2894          石井食品    216.40    216.60   216.0     0.60  0.002770
# 498   2882        イートアンド   1779.96   1781.00  1776.0     5.00  0.002807
# 1641  5344        MARUWA   8078.40   8093.20  8070.0    23.20  0.002867
# 978   3826   システムインテグレータ    849.92    854.48   852.0     2.48  0.002902
# 815   3536  アクサスホールディングス     96.04     96.28    96.0     0.28  0.002908
#
# [100 rows x 7 columns]

# %%
tmp_data2 = tmp_data2.sort_values(by='compare', ascending=False)[0:30]
tmp_data2
# Out:
#         SC                名称  20200611  20200612       株価  compare      rate
# 3288  9022            東海旅客鉄道  18141.20  18183.80  18170.0    13.80  0.000759
# 1360  4568              第一三共   8799.20   8842.48   8832.0    10.48  0.001185
# 386   2587  サントリー食品インターナショナル   4277.00   4289.20   4285.0     4.20  0.000979
# 3125  8393              宮崎銀行   2356.04   2357.04   2355.0     2.04  0.000865
# 3539  9722              藤田観光   1851.36   1853.72   1852.0     1.72  0.000928
# 2385  6967            新光電気工業   1383.44   1384.20   1383.0     1.20  0.000867
# 822   3543       コメダホールディングス   1852.96   1859.04   1858.0     1.04  0.000559
# 1474  4762           エックスネット    970.44    970.96    970.0     0.96  0.000989
# 756   3408         サカイオーベックス   2094.52   2102.92   2102.0     0.92  0.000437
# 2564  7313          テイ・エステック   3014.88   3020.92   3020.0     0.92  0.000305
# 626   3153              八洲電機    878.88    880.80    880.0     0.80  0.000908
# 1535  4929      アジュバンコスメジャパン    947.36    947.72    947.0     0.72  0.000760
# 1613  5237               ノザワ    573.96    574.68    574.0     0.68  0.001183
# 1160  4208              宇部興産   1869.88   1873.60   1873.0     0.60  0.000320
# 2941  8044              大都魚類   1221.72   1221.56   1221.0     0.56  0.000458
# 571   3067           東京一番フーズ    501.92    504.52    504.0     0.52  0.001031
# 1321  4506           大日本住友製薬   1487.08   1486.52   1486.0     0.52  0.000350
# 3217  8802              三菱地所   1724.40   1722.00   1721.5     0.50  0.000290
# 781   3449          テクノフレックス   1150.68   1164.48   1164.0     0.48  0.000412
# 3150  8541              愛媛銀行   1141.96   1143.44   1143.0     0.44  0.000385
# 287   2329              東北新社    580.52    579.44    579.0     0.44  0.000759
# 2327  6870          日本フェンオール   1292.84   1300.40   1300.0     0.40  0.000308
# 3389  9358                宇徳    463.08    463.40    463.0     0.40  0.000863
# 3152  8544              京葉銀行    506.84    506.40    506.0     0.40  0.000790
# 1047  3935              エディア    513.56    514.36    514.0     0.36  0.000700
# 3039  8207            テンアライド    384.80    385.36    385.0     0.36  0.000934
# 3669  9993              ヤマザワ   1719.00   1719.36   1719.0     0.36  0.000209
# 2947  8053              住友商事   1281.30   1280.84   1280.5     0.34  0.000265
# 160   1960             サンテック    595.92    595.32    595.0     0.32  0.000538
# 417   2685            アダストリア   1696.96   1701.32   1701.0     0.32  0.000188
